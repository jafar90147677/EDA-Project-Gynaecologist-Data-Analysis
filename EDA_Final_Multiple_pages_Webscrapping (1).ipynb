# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re

# %%
dr_names = []
spl_col = []
experience = []
Education = []
clinic_fee = []
online_fee = []
clinic_name = []
clinic_location = []
recent_consult = []
start_time = []
end_time = []
city = []

# %%
specialization = [ 'Gynaecologist']

# %%
request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                  'User-Agent': 'Chrome/101.0.0.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                  'Accept-Encoding': 'gzip, deflate, br'}
url = 'https://www.lybrate.com/search?find=Dentist&cityName=Hyderabad&seoRequest=true&page=1'
# running loops for the multiple pages 
for j in specialization:
    count = 0
    for i in range(1,100):
        # connection website
        page = requests.get('https://www.lybrate.com/search?find='+j+'&cityName=Hyderabad&seoRequest=true&page='+str(i))

        # converting str data to html format

        soup = BeautifulSoup(page.text)
        # dr names
        scrape_names = soup.find_all('h2',class_ = 'doctorCard_doctorName__independent__VjX6P')
        for i in scrape_names :
            dr_names.append(i.text)
            spl_col.append(j)
            city.append('Hyderabad')
        
        # experience 
        for i in soup.find_all('div',class_="doctorCard_cardDesc__bq9bD doctorCard_cardOverflow__4D4Ua"):
            
            a = i.text
            if re.findall('(\d+) Years Exp.',a) :
                
                experience.append(re.findall('(\d+) Years Exp.',a)[0])
            else :
                experience.append(np.nan)
        
                            
        # clinic fee 
        for i in soup.find_all('div',class_="doctorCard_cardDesc__bq9bD doctorCard_cardOverflow__4D4Ua") :
    
            if re.findall(r'(₹\s\d+)\sat\sclinic',i.text) :
            
                clinic_fee.append(re.findall(r'(₹\s\d+)\sat\sclinic',i.text)[0])
            else :
                clinic_fee.append(np.nan)
            
            b = re.findall(r'(₹\s\d+)\sonline',i.text)
            if len(b) > 0 :
                online_fee.append(b[0])
            else :
                online_fee.append(np.nan)
        
                            
        # Education
        for i in soup.find_all('div',class_ = 'doctorCard_cardDesc__bq9bD doctorCard_cardOverflow__4D4Ua'):
            if re.findall('Exp\.([A-Za-z\,\s\.\-\(\)\&]+)\₹',i.text) :
                Education.append(re.findall('Exp\.([A-Za-z\,\s\.\-\(\)\&]+)\₹',i.text)[0])
            else :
                Education.append(np.nan)
                       
        #  clinic 
                            
        
        for i in soup.find_all('div',class_="doctorCard_cardDesc__bq9bD doctorCard_cardOverflow__4D4Ua") :
            a = i.text
            if re.findall('\₹\s\d+\sonline(.+derabad)',a) :
                
                loc = re.findall('\₹\s\d+\sonline(.+derabad)',a)[0]
                clinic_name.append(loc.split(',')[0].strip())
                clinic_location.append(loc.split(',')[1].strip())
            else: 
                    if re.findall('\₹\s\d+\sat\sclinic(.+derabad)',a) :

                        loc = re.findall('\₹\s\d+\sat\sclinic(.+derabad)',a)[0]
                        clinic_name.append(loc.split(',')[0].strip())
                        clinic_location.append(loc.split(',')[1].strip())
                    
                    else :
                        clinic_name.append(np.nan)
                        clinic_location.append(np.nan)
                        
        
        
        # recent
        
        for i in soup.find_all('div',class_="doctorCard_cardDesc__bq9bD doctorCard_cardOverflow__4D4Ua"):
            a = i.text
            b = re.findall(r'Recently consulted for:(.+)Avai|Recently consulted for:(.+)See',a)
            if len(b) > 0 :
                if b[0][0] == '' :
                    recent_consult.append(b[0][1])
                else :
                    recent_consult.append(b[0][0])
            else :
                recent_consult.append(np.nan)
                      
        # timings
                            
        
        for i in soup.find_all('div',class_="doctorCard_cardDesc__bq9bD doctorCard_cardOverflow__4D4Ua"):
            a = i.text
            
            b = re.findall(r'\d\d:\d\d\sAM|\d\d:\d\d\sPM',a)
            if len(b) > 0 :
                start_time.append(b[0])
                end_time.append(b[1])
            else :
                start_time.append(np.nan)
                end_time.append(np.nan)
        count += 1
        print(f'{j} Page {count}')
        print(f'Dr names {len(dr_names)}')
        print(f'Spl {len(spl_col)}')
        print(f'Online_fee {len(online_fee)}')
        print(f'clinic_fee {len(clinic_fee)}') 
        print(f'Experience {len(experience)}')
        print(f'Education {len(Education)}')
        print(f'Clinic Name {len(clinic_name)}')
        print(f'Clinic Location {len(clinic_location)}')
        print(f'recent_consult {len(recent_consult)}')
        print(f'start_time {len(start_time)}')
        print(f'end_time {len(end_time)}')
        print('\n')
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\d'
# <>:28: SyntaxWarning: invalid escape sequence '\d'
# <>:51: SyntaxWarning: invalid escape sequence '\.'
# <>:52: SyntaxWarning: invalid escape sequence '\.'
# <>:61: SyntaxWarning: invalid escape sequence '\s'
# <>:63: SyntaxWarning: invalid escape sequence '\s'
# <>:67: SyntaxWarning: invalid escape sequence '\s'
# <>:69: SyntaxWarning: invalid escape sequence '\s'
# <>:26: SyntaxWarning: invalid escape sequence '\d'
# <>:28: SyntaxWarning: invalid escape sequence '\d'
# <>:51: SyntaxWarning: invalid escape sequence '\.'
# <>:52: SyntaxWarning: invalid escape sequence '\.'
# <>:61: SyntaxWarning: invalid escape sequence '\s'
# <>:63: SyntaxWarning: invalid escape sequence '\s'
# <>:67: SyntaxWarning: invalid escape sequence '\s'
# <>:69: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ooha2\AppData\Local\Temp\ipykernel_10864\717430579.py:26: SyntaxWarning: invalid escape sequence '\d'
#   if re.findall('(\d+) Years Exp.',a) :
# C:\Users\ooha2\AppData\Local\Temp\ipykernel_10864\717430579.py:28: SyntaxWarning: invalid escape sequence '\d'
#   experience.append(re.findall('(\d+) Years Exp.',a)[0])
# C:\Users\ooha2\AppData\Local\Temp\ipykernel_10864\717430579.py:51: SyntaxWarning: invalid escape sequence '\.'
#   if re.findall('Exp\.([A-Za-z\,\s\.\-\(\)\&]+)\₹',i.text) :
# C:\Users\ooha2\AppData\Local\Temp\ipykernel_10864\717430579.py:52: SyntaxWarning: invalid escape sequence '\.'
#   Education.append(re.findall('Exp\.([A-Za-z\,\s\.\-\(\)\&]+)\₹',i.text)[0])
# C:\Users\ooha2\AppData\Local\Temp\ipykernel_10864\717430579.py:61: SyntaxWarning: invalid escape sequence '\s'
#   if re.findall('\₹\s\d+\sonline(.+derabad)',a) :
# C:\Users\ooha2\AppData\Local\Temp\ipykernel_10864\717430579.py:63: SyntaxWarning: invalid escape sequence '\s'
#   loc = re.findall('\₹\s\d+\sonline(.+derabad)',a)[0]
# C:\Users\ooha2\AppData\Local\Temp\ipykernel_10864\717430579.py:67: SyntaxWarning: invalid escape sequence '\s'
#   if re.findall('\₹\s\d+\sat\sclinic(.+derabad)',a) :
# C:\Users\ooha2\AppData\Local\Temp\ipykernel_10864\717430579.py:69: SyntaxWarning: invalid escape sequence '\s'
#   loc = re.findall('\₹\s\d+\sat\sclinic(.+derabad)',a)[0]
# Gynaecologist Page 1
# Dr names 10
# Spl 10
# Online_fee 10
# clinic_fee 10
# Experience 10
# Education 10
# Clinic Name 10
# Clinic Location 10
# recent_consult 10
# start_time 10
# end_time 10
#
#
# Gynaecologist Page 2
# Dr names 20
# Spl 20
# Online_fee 20
# clinic_fee 20
# Experience 20
# Education 20
# Clinic Name 20
# Clinic Location 20
# recent_consult 20
# start_time 20
# end_time 20
#
#
# Gynaecologist Page 3
# Dr names 30
# Spl 30
# Online_fee 30
# clinic_fee 30
# Experience 30
# Education 30
# Clinic Name 30
# Clinic Location 30
# recent_consult 30
# start_time 30
# end_time 30
#
#
# Gynaecologist Page 4
# Dr names 40
# Spl 40
# Online_fee 40
# clinic_fee 40
# Experience 40
# Education 40
# Clinic Name 40
# Clinic Location 40
# recent_consult 40
# start_time 40
# end_time 40
#
#
# Gynaecologist Page 5
# Dr names 50
# Spl 50
# Online_fee 50
# clinic_fee 50
# Experience 50
# Education 50
# Clinic Name 50
# Clinic Location 50
# recent_consult 50
# start_time 50
# end_time 50
#
#
# Gynaecologist Page 6
# Dr names 60
# Spl 60
# Online_fee 60
# clinic_fee 60
# Experience 60
# Education 60
# Clinic Name 60
# Clinic Location 60
# recent_consult 60
# start_time 60
# end_time 60
#
#
# Gynaecologist Page 7
# Dr names 70
# Spl 70
# Online_fee 70
# clinic_fee 70
# Experience 70
# Education 70
# Clinic Name 70
# Clinic Location 70
# recent_consult 70
# start_time 70
# end_time 70
#
#
# Gynaecologist Page 8
# Dr names 80
# Spl 80
# Online_fee 80
# clinic_fee 80
# Experience 80
# Education 80
# Clinic Name 80
# Clinic Location 80
# recent_consult 80
# start_time 80
# end_time 80
#
#
# Gynaecologist Page 9
# Dr names 90
# Spl 90
# Online_fee 90
# clinic_fee 90
# Experience 90
# Education 90
# Clinic Name 90
# Clinic Location 90
# recent_consult 90
# start_time 90
# end_time 90
#
#
# Gynaecologist Page 10
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 11
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 12
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 13
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 14
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 15
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 16
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 17
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 18
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 19
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 20
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 21
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 22
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 23
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 24
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 25
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 26
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 27
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 28
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 29
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 30
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 31
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 32
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 33
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 34
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 35
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 36
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 37
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 38
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 39
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 40
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 41
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 42
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 43
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 44
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 45
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 46
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 47
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 48
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 49
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 50
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 51
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 52
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 53
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 54
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 55
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 56
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 57
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 58
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 59
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 60
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 61
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 62
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 63
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 64
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 65
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 66
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 67
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 68
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 69
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 70
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 71
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 72
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 73
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 74
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 75
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 76
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 77
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 78
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 79
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 80
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 81
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 82
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 83
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 84
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 85
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 86
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 87
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 88
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 89
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 90
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 91
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 92
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 93
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 94
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 95
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 96
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 97
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 98
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100
#
#
# Gynaecologist Page 99
# Dr names 100
# Spl 100
# Online_fee 100
# clinic_fee 100
# Experience 100
# Education 100
# Clinic Name 100
# Clinic Location 100
# recent_consult 100
# start_time 100
# end_time 100

# %%
d = {'Name':dr_names,
     'Specialization' : spl_col,
    'Experience (in years)':experience,
    'Education':Education,
    'Fee at clinic':clinic_fee,
    'Online Fee':online_fee,
     'Clinic Name':clinic_name,
     'Area':clinic_location,
     'Recently Consulted for':recent_consult,
     'Available From':start_time,
     'Available Till' : end_time,
     'City' : city
    }
df = pd.DataFrame(d)
df
# Out:
#                       Name Specialization Experience (in years)  \
# 0        Dr. Sindhuri Kapu  Gynaecologist                    13
# 1   Dr. Juhul Arvind Patel  Gynaecologist                     8
# 2              Dr. Paipuru  Gynaecologist                   NaN
# 3        Dr M Swapna Reddy  Gynaecologist                    17
# 4         Dr. Sadhvi Reddy  Gynaecologist                    14
# ..                     ...            ...                   ...
# 95            Dr. Nivedita  Gynaecologist                    25
# 96             Dr. Neelima  Gynaecologist                    28
# 97            Anusha Patel  Gynaecologist                    14
# 98     Dr. Manjula Anagani  Gynaecologist                    33
# 99      Dr. K Padmaja Devi  Gynaecologist                    33
#
#                                             Education Fee at clinic  \
# 0                 MBBS, DNB - Obstetrics & Gynecology         ₹ 800
# 1   DNB, DGO, Dip. Hospital Administration, Diplom...         ₹ 500
# 2                                                 NaN         ₹ 500
# 3                                           MBBS, DGO         ₹ 500
# 4   Fellowship  In Minimal Access Surgery, MS - Ob...         ₹ 500
# ..                                                ...           ...
# 95                MBBS, MD - Obstetrics & Gynaecology         ₹ 500
# 96  MBBS, MD - Obstetrics & Gynaecology, Fellowshi...         ₹ 500
# 97                                       MBBS, MS OBG         ₹ 300
# 98  MBBS, Internship, MD (Pathology), MD (Gynaecol...           NaN
# 99                                          MBBS, DGO         ₹ 450
#
#    Online Fee                                        Clinic Name  \
# 0       ₹ 500  Ankura Hospital for Women & Children - Banjara...
# 1       ₹ 300                                       Pristyn Care
# 2         NaN                                Pristyn Care Clinic
# 3         NaN                                       Pristyn care
# 4       ₹ 500                                     Vijay Hospital
# ..        ...                                                ...
# 95        NaN                Srishti Women's CLinic    (On Call)
# 96        NaN                                   Neelima Hospital
# 97      ₹ 300                               Habsiguda Polyclinic
# 98        NaN                                                NaN
# 99        NaN                                      Sneha Clinics
#
#              Area                        Recently Consulted for  \
# 0       Hyderabad                                           NaN
# 1       Hyderabad                                           NaN
# 2   Banjara Hills                                           NaN
# 3       Hyderabad                                           NaN
# 4    Dilsukhnagar  No Periods, Sex Education, Irregular Periods
# ..            ...                                           ...
# 95        Tarnaka                                           NaN
# 96     Moti Nagar                                           NaN
# 97      Hyderabad                                           NaN
# 98            NaN                                           NaN
# 99           KPHB                                           NaN
#
#    Available From Available Till       City
# 0        10:00 AM       06:00 PM  Hyderabad
# 1        10:00 AM       08:00 PM  Hyderabad
# 2        05:00 PM       08:00 PM  Hyderabad
# 3        09:00 AM       06:30 PM  Hyderabad
# 4        11:00 AM       05:00 PM  Hyderabad
# ..            ...            ...        ...
# 95       10:00 AM       05:00 PM  Hyderabad
# 96       04:00 PM       08:00 PM  Hyderabad
# 97       05:00 PM       08:00 PM  Hyderabad
# 98       11:00 AM       01:00 PM  Hyderabad
# 99       09:00 AM       01:30 PM  Hyderabad
#
# [100 rows x 12 columns]

# %%
df['Recently Consulted for'].unique()
# Out:
# array([nan, 'No Periods, Sex Education, Irregular Periods',
#        'No Periods, Pregnancy Query, Irregular Periods',
#        'No Periods, Irregular Periods, Pregnancy', 'Pregnancy',
#        'Pregnancy, HPV, Abortion',
#        'No Periods, Sex Education, Pregnancy QueryNext ',
#        'Irregular Periods, Delivery', 'Sugar'], dtype=object)

# %%
new = []
for i in df['Recently Consulted for'] :
    if type(i) == str:
        new.append(i.replace('Next',''))
    else :
        new.append(i)

# %%
df['Recently Consulted for'] = new

# %%
df
# Out:
#                       Name Specialization Experience (in years)  \
# 0        Dr. Sindhuri Kapu  Gynaecologist                    13
# 1   Dr. Juhul Arvind Patel  Gynaecologist                     8
# 2              Dr. Paipuru  Gynaecologist                   NaN
# 3        Dr M Swapna Reddy  Gynaecologist                    17
# 4         Dr. Sadhvi Reddy  Gynaecologist                    14
# ..                     ...            ...                   ...
# 95            Dr. Nivedita  Gynaecologist                    25
# 96             Dr. Neelima  Gynaecologist                    28
# 97            Anusha Patel  Gynaecologist                    14
# 98     Dr. Manjula Anagani  Gynaecologist                    33
# 99      Dr. K Padmaja Devi  Gynaecologist                    33
#
#                                             Education Fee at clinic  \
# 0                 MBBS, DNB - Obstetrics & Gynecology         ₹ 800
# 1   DNB, DGO, Dip. Hospital Administration, Diplom...         ₹ 500
# 2                                                 NaN         ₹ 500
# 3                                           MBBS, DGO         ₹ 500
# 4   Fellowship  In Minimal Access Surgery, MS - Ob...         ₹ 500
# ..                                                ...           ...
# 95                MBBS, MD - Obstetrics & Gynaecology         ₹ 500
# 96  MBBS, MD - Obstetrics & Gynaecology, Fellowshi...         ₹ 500
# 97                                       MBBS, MS OBG         ₹ 300
# 98  MBBS, Internship, MD (Pathology), MD (Gynaecol...           NaN
# 99                                          MBBS, DGO         ₹ 450
#
#    Online Fee                                        Clinic Name  \
# 0       ₹ 500  Ankura Hospital for Women & Children - Banjara...
# 1       ₹ 300                                       Pristyn Care
# 2         NaN                                Pristyn Care Clinic
# 3         NaN                                       Pristyn care
# 4       ₹ 500                                     Vijay Hospital
# ..        ...                                                ...
# 95        NaN                Srishti Women's CLinic    (On Call)
# 96        NaN                                   Neelima Hospital
# 97      ₹ 300                               Habsiguda Polyclinic
# 98        NaN                                                NaN
# 99        NaN                                      Sneha Clinics
#
#              Area                        Recently Consulted for  \
# 0       Hyderabad                                           NaN
# 1       Hyderabad                                           NaN
# 2   Banjara Hills                                           NaN
# 3       Hyderabad                                           NaN
# 4    Dilsukhnagar  No Periods, Sex Education, Irregular Periods
# ..            ...                                           ...
# 95        Tarnaka                                           NaN
# 96     Moti Nagar                                           NaN
# 97      Hyderabad                                           NaN
# 98            NaN                                           NaN
# 99           KPHB                                           NaN
#
#    Available From Available Till       City
# 0        10:00 AM       06:00 PM  Hyderabad
# 1        10:00 AM       08:00 PM  Hyderabad
# 2        05:00 PM       08:00 PM  Hyderabad
# 3        09:00 AM       06:30 PM  Hyderabad
# 4        11:00 AM       05:00 PM  Hyderabad
# ..            ...            ...        ...
# 95       10:00 AM       05:00 PM  Hyderabad
# 96       04:00 PM       08:00 PM  Hyderabad
# 97       05:00 PM       08:00 PM  Hyderabad
# 98       11:00 AM       01:00 PM  Hyderabad
# 99       09:00 AM       01:30 PM  Hyderabad
#
# [100 rows x 12 columns]

# %%
df.to_csv('Eda_Final_project_305_Multiple_Pages.csv')

# %%
df.isnull().sum()
# Out:
# Name                       0
# Specialization             0
# Experience (in years)      3
# Education                  4
# Fee at clinic              7
# Online Fee                66
# Clinic Name                7
# Area                       7
# Recently Consulted for    91
# Available From             0
# Available Till             0
# City                       0
# dtype: int64

# %%
df
# Out:
#                       Name Specialization Experience (in years)  \
# 0        Dr. Sindhuri Kapu  Gynaecologist                    13
# 1   Dr. Juhul Arvind Patel  Gynaecologist                     8
# 2              Dr. Paipuru  Gynaecologist                   NaN
# 3        Dr M Swapna Reddy  Gynaecologist                    17
# 4         Dr. Sadhvi Reddy  Gynaecologist                    14
# ..                     ...            ...                   ...
# 95            Dr. Nivedita  Gynaecologist                    25
# 96             Dr. Neelima  Gynaecologist                    28
# 97            Anusha Patel  Gynaecologist                    14
# 98     Dr. Manjula Anagani  Gynaecologist                    33
# 99      Dr. K Padmaja Devi  Gynaecologist                    33
#
#                                             Education Fee at clinic  \
# 0                 MBBS, DNB - Obstetrics & Gynecology         ₹ 800
# 1   DNB, DGO, Dip. Hospital Administration, Diplom...         ₹ 500
# 2                                                 NaN         ₹ 500
# 3                                           MBBS, DGO         ₹ 500
# 4   Fellowship  In Minimal Access Surgery, MS - Ob...         ₹ 500
# ..                                                ...           ...
# 95                MBBS, MD - Obstetrics & Gynaecology         ₹ 500
# 96  MBBS, MD - Obstetrics & Gynaecology, Fellowshi...         ₹ 500
# 97                                       MBBS, MS OBG         ₹ 300
# 98  MBBS, Internship, MD (Pathology), MD (Gynaecol...           NaN
# 99                                          MBBS, DGO         ₹ 450
#
#    Online Fee                                        Clinic Name  \
# 0       ₹ 500  Ankura Hospital for Women & Children - Banjara...
# 1       ₹ 300                                       Pristyn Care
# 2         NaN                                Pristyn Care Clinic
# 3         NaN                                       Pristyn care
# 4       ₹ 500                                     Vijay Hospital
# ..        ...                                                ...
# 95        NaN                Srishti Women's CLinic    (On Call)
# 96        NaN                                   Neelima Hospital
# 97      ₹ 300                               Habsiguda Polyclinic
# 98        NaN                                                NaN
# 99        NaN                                      Sneha Clinics
#
#              Area                        Recently Consulted for  \
# 0       Hyderabad                                           NaN
# 1       Hyderabad                                           NaN
# 2   Banjara Hills                                           NaN
# 3       Hyderabad                                           NaN
# 4    Dilsukhnagar  No Periods, Sex Education, Irregular Periods
# ..            ...                                           ...
# 95        Tarnaka                                           NaN
# 96     Moti Nagar                                           NaN
# 97      Hyderabad                                           NaN
# 98            NaN                                           NaN
# 99           KPHB                                           NaN
#
#    Available From Available Till       City
# 0        10:00 AM       06:00 PM  Hyderabad
# 1        10:00 AM       08:00 PM  Hyderabad
# 2        05:00 PM       08:00 PM  Hyderabad
# 3        09:00 AM       06:30 PM  Hyderabad
# 4        11:00 AM       05:00 PM  Hyderabad
# ..            ...            ...        ...
# 95       10:00 AM       05:00 PM  Hyderabad
# 96       04:00 PM       08:00 PM  Hyderabad
# 97       05:00 PM       08:00 PM  Hyderabad
# 98       11:00 AM       01:00 PM  Hyderabad
# 99       09:00 AM       01:30 PM  Hyderabad
#
# [100 rows x 12 columns]

# %%
df['Area'].unique()
# Out:
# array(['Hyderabad', 'Banjara Hills', 'Dilsukhnagar', 'Kukatpally',
#        'Habsiguda', '000 onlineEVA Care Clinic- The Every Woman?s Clinic',
#        'L B Nagar', 'Hastinapuram', 'Kondapur', 'KPHB',
#        'Test Tube&Fertility  Centre', nan, 'Shaikpet', 'Basheerbagh',
#        'Ramanthapur', 'Masab Tank', 'Kothapet', 'Nizampet', 'Madhapur',
#        'Nagole', 'Gachibowli', 'Vanasthalipuram', 'Nanakramguda', 'Alwal',
#        'Toli Chowki', 'Kothaguda', 'Mehdipatnam', 'Nacharam', 'Hafeezpet',
#        'Jeedimetla', 'West Marredpally',
#        'Orthopaedic And General Hospital', 'Malakpet', 'Sri Nagar Colony',
#        'Maternity and General', 'Saidabad', 'Moti Nagar',
#        'East Marredpally', 'hyderabad', 'Jubilee Hills', 'Tarnaka'],
#       dtype=object)
